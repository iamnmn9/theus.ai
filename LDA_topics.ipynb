# %% [markdown]
# ##IMPORTS

# %%
import pandas as pd
import numpy as np
# !pip install pdfplumber pandas
# Out:
# Collecting pdfplumber
#   Downloading pdfplumber-0.10.2-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.5/47.5 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Collecting pdfminer.six==20221105 (from pdfplumber)
#   Downloading pdfminer.six-20221105-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 52.6 MB/s eta 0:00:00
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from pdfplumber) (9.4.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Downloading pypdfium2-4.19.0-py3-none-manylinux_2_17_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 78.0 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20221105->pdfplumber) (3.2.0)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20221105->pdfplumber) (41.0.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber) (2.21)
# Installing collected packages: pypdfium2, pdfminer.six, pdfplumber
# Successfully installed pdfminer.six-20221105 pdfplumber-0.10.2 pypdfium2-4.19.0

# %% [markdown]
# ##Data: Book: Choose Your Enemies Wisely: Business Planning for the Audacious Few
# Book by Patrick Bet-David

# %%
import pdfplumber
import pandas as pd

pdf_path = '/content/nmy.pdf'
data = []

with pdfplumber.open(pdf_path) as pdf:
    for page_num in range(len(pdf.pages)):
        page = pdf.pages[page_num]
        text = page.extract_text()
        data.append({'Text': text})

df = pd.DataFrame(data)
print(df)
# Out:
#                                                   Text
# 0
# 1    Thank you for downloading\nthis Simon & Schust...
# 2
# 3    To my father, Gabreal Bet-David, the Aristotle...
# 4    Author’s Note\nI tell stories that go back mor...
# ..                                                 ...
# 275  About the Author\nPatrick Bet-David went from ...
# 276                SimonandSchuster.com\n@GalleryBooks
# 277  We hope you enjoyed\nreading this Simon &\nSch...
# 278  Gallery Books\nAn Imprint of Simon & Schuster,...
# 279  Classication: LCC HD30.28 .B4585 2020 (print)...
#
# [280 rows x 1 columns]

# %% [markdown]
# ##Data Processing

# %%
df.dropna(axis=1, how='all', inplace=True)

# %%
df = df[df.apply(lambda row: row.str.strip().ne('').any(), axis=1)]

# %%
df
# Out:
#                                                   Text
# 1    Thank you for downloading\nthis Simon & Schust...
# 3    To my father, Gabreal Bet-David, the Aristotle...
# 4    Author’s Note\nI tell stories that go back mor...
# 5    Introduction\nBefore Your First Move\nWhen I ...
# 6    prepared to launch another series of moves bas...
# ..                                                 ...
# 275  About the Author\nPatrick Bet-David went from ...
# 276                SimonandSchuster.com\n@GalleryBooks
# 277  We hope you enjoyed\nreading this Simon &\nSch...
# 278  Gallery Books\nAn Imprint of Simon & Schuster,...
# 279  Classication: LCC HD30.28 .B4585 2020 (print)...
#
# [274 rows x 1 columns]

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import string


nltk.download('punkt')
nltk.download('stopwords')


df = pd.DataFrame(df)

df['Text'] = df['Text'].apply(lambda x: x.lower())

df['Text'] = df['Text'].apply(lambda x: word_tokenize(x))
df['Text'] = df['Text'].apply(lambda tokens: [token for token in tokens if token not in string.punctuation])
stop_words = set(stopwords.words('english'))
df['Text'] = df['Text'].apply(lambda tokens: [token for token in tokens if token not in stop_words])

stemmer = PorterStemmer()
df['Text'] = df['Text'].apply(lambda tokens: [stemmer.stem(token) for token in tokens])

df['Text'] = df['Text'].apply(lambda tokens: ' '.join(tokens))

print(df)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#                                                   Text
# 1    thank download simon schuster ebook get free e...
# 3               father gabreal bet-david aristotl life
# 4    author ’ note tell stori go back thirti year b...
# 5    introduct first move rst watch magnu document...
# 6    prepar launch anoth seri move base market comp...
# ..                                                 ...
# 275  author patrick bet-david went escap war-torn i...
# 276                   simonandschuster.com gallerybook
# 277  hope enjoy read simon schuster ebook get free ...
# 278  galleri book imprint simon schuster inc. 1230 ...
# 279  classic lcc hd30.28 .b4585 2020 print lcc hd3...
#
# [274 rows x 1 columns]

# %%
df
# Out:
#                                                   Text
# 1    Thank you for downloading\nthis Simon & Schust...
# 3    To my father, Gabreal Bet-David, the Aristotle...
# 4    Author’s Note\nI tell stories that go back mor...
# 5    Introduction\nBefore Your First Move\nWhen I ...
# 6    prepared to launch another series of moves bas...
# ..                                                 ...
# 275  About the Author\nPatrick Bet-David went from ...
# 276                SimonandSchuster.com\n@GalleryBooks
# 277  We hope you enjoyed\nreading this Simon &\nSch...
# 278  Gallery Books\nAn Imprint of Simon & Schuster,...
# 279  Classication: LCC HD30.28 .B4585 2020 (print)...
#
# [274 rows x 1 columns]

# %% [markdown]
# ##TOPIC MODELLING with our data

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

vectorizer = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
dtm = vectorizer.fit_transform(df['Text'])

# %%
dtm
# Out:
# <274x3583 sparse matrix of type '<class 'numpy.int64'>'
# 	with 27088 stored elements in Compressed Sparse Row format>

# %%
from sklearn.decomposition import LatentDirichletAllocation

num_topics = 50
lda = LatentDirichletAllocation(n_components=num_topics, random_state=42)

lda.fit(dtm)
# Out:
# LatentDirichletAllocation(n_components=50, random_state=42)

# %%
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = f"Topic #{topic_idx + 1}: "
        message += " ".join([feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)

n_top_words = 10
feature_names = vectorizer.get_feature_names_out()

print_top_words(lda, feature_names, n_top_words)
# Out:
# Topic #1: insurance people narrative don nancial things competitors time result sell
# Topic #2: company make business going time people need identify making want
# Topic #3: want people ve moves business know need time life don
# Topic #4: recognition need praise pressure don plaque ayrton senna knowing erent
# Topic #5: time speed make business day week ve want going don
# Topic #6: make time right processing people pat result check big going
# Topic #7: said like people want rogan erent di truth life future
# Topic #8: 000 people cost savings year policies business time help project
# Topic #9: father michael ebook think meeting schuster click sign simon life
# Topic #10: trouble ectively systems speed manage business dangerous chaos build world
# Topic #11: investment ask company phase start need want ce ma started
# Topic #12: people make business better don life person burry trust want
# Topic #13: lived deal power options customer leverage like iran don dad
# Topic #14: business people systems time make company want need don hire
# Topic #15: going lions lion moves data looking understand company want say
# Topic #16: time business money need 000 company think going investment like
# Topic #17: like intrapreneur people company entrepreneur want said don just new
# Topic #18: people trust time don business speed know like want good
# Topic #19: make world alice defense entrepreneurs pistone solve ve fbi business
# Topic #20: process need ve old steps real product going growth fact
# Topic #21: data business systems help make moneyball analytics scale baseball applied
# Topic #22: peter management life entrepreneurship eric 33 leadership war growing build
# Topic #23: list moves ve grand fteen make master identify consider book
# Topic #24: business people work di things success deal world little life
# Topic #25: business make bynum people ve way company ceo want strategy
# Topic #26: blame want ones moments rmations positive great ve use say
# Topic #27: people want lost like things feel best just years level
# Topic #28: momentum downey walsh want ve head don assistants talk coaches
# Topic #29: zig expectation expert experiencing experiences experienced experience expensive expenses expense
# Topic #30: ve money wrong predictions peter people lead entrepreneurs team spend
# Topic #31: issues business solve problem process make processing nd based situation
# Topic #32: crisis time ve looked going pounds said breaking start di
# Topic #33: people company don ibm great want like going years percent
# Topic #34: goliath better goliaths business know knowing beat isn don bigger
# Topic #35: people sheena matt say make time know faster function said
# Topic #36: people want company going don say know business pressure make
# Topic #37: people want make business person wrong money right transferable rst
# Topic #38: people chris data ll make processors best need di thinking
# Topic #39: people meeting business sit rst power tough company master plays
# Topic #40: business amazon company trillion wise years need love people dollars
# Topic #41: business ll make people know company customer time ve trust
# Topic #42: think moves don ahead vision content salesman master ve chess
# Topic #43: care aegon list just leaders business fortune easy ve success
# Topic #44: ve business people ll just time think company want don
# Topic #45: people know need want say way best love danny don
# Topic #46: believe leverage people selling negotiation sell know believing win business
# Topic #47: michael dale meeting darius issues rogan guy processing like responsibility
# Topic #48: team said going ll master ve business jordan corcoran age
# Topic #49: people business problem make parson solve going know formula sales
# Topic #50: audit personal questions identity life want answer person important having
